# %% [markdown]
# <a href="https://colab.research.google.com/github/amar7779/assignment2/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
! pip install kaggle

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras import layers, models
from sklearn.preprocessing import RobustScaler # This line has been added
from imblearn.over_sampling import SMOTE
from tensorflow.keras import layers, models

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ryanholbrook/dl-course-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/dl-course-data

# %%
df = pd.read_csv(f"{path}/hotel.csv")
x = df.copy()
y = x.pop('is_canceled')

# %%
# Train/Val/Test Split
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
print(x_train.dtypes)
# Out:
# hotel                              object
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# ...

# %%
#just to try underfitting no preprocessing

# Combine training and validation to encode consistently
combined = pd.concat([x_train, x_val])
combined_encoded = pd.get_dummies(combined)

# Split them back
x_train_encoded = combined_encoded.iloc[:len(x_train)]
x_val_encoded = combined_encoded.iloc[len(x_train):]

# %%
x_train = x_train_encoded.astype('float32')
x_val = x_val_encoded.astype('float32')
y_train = y_train.astype('float32')
y_val = y_val.astype('float32')

# %%
import tensorflow as tf

def build_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Recall()]
    )
    return model

# %%
adam_model=build_model(tf.keras.optimizers.Adam(learning_rate=0.001))
history = adam_model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=10,
    batch_size=32
)
# Out:
# Epoch 1/10
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.6321 - loss: nan - recall_5: 0.0000e+00 - val_accuracy: 0.6239 - val_loss: nan - val_recall_5: 0.0000e+00
# Epoch 2/10
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6321 - loss: nan - recall_5: 0.0000e+00 - val_accuracy: 0.6239 - val_loss: nan - val_recall_5: 0.0000e+00
# Epoch 3/10
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6292 - loss: nan - recall_5: 0.0000e+00 - val_accuracy: 0.6239 - val_loss: nan - val_recall_5: 0.0000e+00
# Epoch 4/10
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.6301 - loss: nan - recall_5: 0.0000e+00 - val_accuracy: 0.6239 - val_loss: nan - val_recall_5: 0.0000e+00
# Epoch 5/10
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6298 - loss: nan - recall_5: 0.0000e+00 - val_accuracy: 0.6239 - val_loss: nan - val_recall_5: 0.0000e+00
# Epoch 6/10
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#start encoding
#print(df['hotel'].value_counts())
df= pd.get_dummies(df, columns=['hotel'],dtype=int)

# %%
df=pd.get_dummies(df,columns=['reservation_status'],dtype=int)

# %%
df=pd.get_dummies(df,columns=['customer_type'],dtype=int)

# %%
print(df.dtypes)
# Out:
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# ...

# %%
df = pd.get_dummies(df, columns=['meal'], dtype=int)

# %%
country_mean = df.groupby('country')['is_canceled'].mean()

df['country'] = df['country'].map(country_mean)

# %%
print(df['market_segment'].value_counts())
print(df['distribution_channel'].value_counts())
print(df['reserved_room_type'].value_counts())
print(df['assigned_room_type'].value_counts())
print(df['deposit_type'].value_counts())
print(df[''].value_counts())
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64
# reserved_room_type
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64
# assigned_room_type
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64
# reservation_status_date
# 2015-10-21    1461
# 2015-07-06     805
# 2016-11-25     790
# ...

# %%
import pandas as pd
label_encoder = LabelEncoder()
df['reserved_room_type'] = label_encoder.fit_transform(df['reserved_room_type'])
df['assigned_room_type'] = label_encoder.fit_transform(df['assigned_room_type'])

# %%
df_encoded = pd.get_dummies(df, columns=['market_segment', 'distribution_channel'
                                          ,'deposit_type'], dtype=int)

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# Extract year and month
df['year'] = df['reservation_status_date'].dt.year
df['month'] = df['reservation_status_date'].dt.month

# %%
df = df.drop(df.select_dtypes(include=['object']).columns, axis=1)

# %%
df.isnull().sum()
# Out:
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# country                              488
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# ...

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns


for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=df[col], color='skyblue')
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %%
correlation=df.corr()

# %%
plt.figure(figsize=(14,14))
sns.heatmap(
    correlation,
    cbar=True,
    square=True,
    fmt='.1f',
    annot=True,
    annot_kws={'size': 8},
    cmap='Blues'
)
# Out:
# <Axes: >

# %%
df=df.drop(['reservation_status_Canceled'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-18b1c2e02431> in <cell line: 0>()
# ----> 1 df=df.drop(['reservation_status_Canceled'],axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
columns_to_drop = [
    'reservation_status_Canceled',
    'reservation_status_Check-out',
    'reservation_status_No-Show',
    'reservation_status_date',
    'reserved_room_type',
]


df_cleaned = df.drop(columns=columns_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-70878918a842> in <cell line: 0>()
#       8
#       9
# ---> 10 df_cleaned = df.drop(columns=columns_to_drop)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df=df.drop(['reservation_status_date'],axis=1)

# %%
df=df.drop(['arrival_date_week_number'],axis=1)

# %%
df=df.drop(['customer_type_Transient'],axis=1)

# %%
df=df.drop(['reserved_room_type'],axis=1)
df=df.drop(['meal_FB'],axis=1)
df=df.drop(['meal_BB'],axis=1)
df=df.drop(['meal_HB'],axis=1)
df=df.drop(['meal_SC'],axis=1)

# %%
plt.figure(figsize=(14,14))
sns.heatmap(
    correlation,
    cbar=True,
    square=True,
    fmt='.1f',
    annot=True,
    annot_kws={'size': 8},
    cmap='Blues'
)
# Out:
# <Axes: >

# %%
x = df.drop(columns=['is_canceled', 'reservation_status_date'])  # Drop the problematic column
y = df['is_canceled']


x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

scaler = RobustScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-166-2635a091d3f9> in <cell line: 0>()
# ----> 1 x = df.drop(columns=['is_canceled', 'reservation_status_date'])  # Drop the problematic column
#       2 y = df['is_canceled']
#       3
#       4 # Train/Val/Test Split
#       5 x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
# ...

# %%
import tensorflow as tf

def build_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc')
        ]
    )

    return model

adam_model = build_model(tf.keras.optimizers.Adam(learning_rate=0.001))

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    mode='max',
    restore_best_weights=True
)

history = adam_model.fit(
    x_train_scaled, y_train,
    validation_data=(x_val_scaled, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.9592 - auc: 0.9770 - loss: 0.1672 - val_accuracy: 0.9975 - val_auc: 1.0000 - val_loss: 0.0163
# Epoch 2/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9842 - auc: 0.9931 - loss: 0.0606 - val_accuracy: 0.9998 - val_auc: 1.0000 - val_loss: 0.0113
# Epoch 3/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9876 - auc: 0.9944 - loss: 0.0499 - val_accuracy: 0.9992 - val_auc: 1.0000 - val_loss: 0.0061
# Epoch 4/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.9886 - auc: 0.9949 - loss: 0.0462 - val_accuracy: 0.9999 - val_auc: 1.0000 - val_loss: 0.0064
# Epoch 5/100
#   51/2985 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9890 - auc: 0.9939 - loss: 0.0481
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-167-e1e33abe370f> in <cell line: 0>()
#      34
# ...

# %%
import tensorflow as tf
from sklearn.metrics import f1_score


def f1_score_metric(y_true, y_pred):
    y_pred_binary = tf.round(y_pred)

    f1 = tf.numpy_function(f1_score, (y_true, y_pred_binary), tf.float64)

    return tf.cast(tf.reshape(f1, []), tf.float32)


def build_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Recall(name='recall'),
            f1_score_metric
        ]
    )

    return model


adam_model = build_model(tf.keras.optimizers.Adam(learning_rate=0.001))


early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    mode='max',
    restore_best_weights=True
)


history = adam_model.fit(
    x_train_scaled, y_train,
    validation_data=(x_val_scaled, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 30s 9ms/step - accuracy: 0.9574 - auc: 0.9794 - f1_score_metric: 0.9331 - loss: 0.1477 - recall: 0.9112 - val_accuracy: 0.9997 - val_auc: 1.0000 - val_f1_score_metric: 0.9997 - val_loss: 0.0155 - val_recall: 0.9993
# Epoch 2/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - accuracy: 0.9839 - auc: 0.9923 - f1_score_metric: 0.9765 - loss: 0.0635 - recall: 0.9616 - val_accuracy: 0.9999 - val_auc: 1.0000 - val_f1_score_metric: 0.9999 - val_loss: 0.0076 - val_recall: 0.9998
# Epoch 3/100
# 2985/2985 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - accuracy: 0.9873 - auc: 0.9940 - f1_score_metric: 0.9819 - loss: 0.0520 - recall: 0.9689 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score_metric: 1.0000 - val_loss: 0.0126 - val_recall: 1.0000
# Epoch 4/100
# ...

# %%
# THERE IS DATA LEAKAGE I DON'T how to handle that
